# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
data = pd.read_csv("news.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
padding_type = 'post'
trunc_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = 0.1

# %%
title = []
text = []
labels = []
for x in range(training_size):
    title.append(data['title'][x])
    text.append(data['text'][x])
    labels.append(data['label'][x])

tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(sequences1, padding=padding_type, truncating=trunc_type)

# %%
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
training_sequences1 = np.array(training_sequences1)
test_sequences1 = np.array(test_sequences1)

# %%
import urllib.request
import os

url = "https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip"
filename = "glove.6B.zip"

def show_progress(block_num, block_size, total_size):
    downloaded = block_num * block_size
    percent = min(downloaded * 100 / total_size, 100)
    print(
        f"\rDownloaded: {downloaded / (1024**2):.1f} MB "
        f"/ {total_size / (1024**2):.1f} MB "
        f"({percent:.1f}%)",
        end=""
    )

urllib.request.urlretrieve(
    url,
    filename,
    reporthook=show_progress
)

print("\nDownload complete.")
# Out:
# Downloaded: 822.2 MB / 822.2 MB (100.0%)
# Download complete.

# %%
embedding_index = {}
with open('glove.6B/glove.6B.50d.txt', 'r', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = coefs
        
embedding_matrix = np.zeros((vocab_size1 + 1, embedding_dim))

for word, i in word_index1.items():
    if i < vocab_size1:
        embedding_vector = embedding_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size1 + 1, embedding_dim, input_length=max_length, 
                              weights=[embedding_matrix], trainable=False),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# c:\Users\Ashok\OneDrive\Desktop\fakenewsdetectionmodelusingtensorflow\venv\Lib\site-packages\keras\src\layers\core\embedding.py:123: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │       377,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 377,600 (1.44 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 377,600 (1.44 MB)

# %%
history = model.fit(
    training_sequences1, 
    np.array(training_labels), 
    epochs=50, 
    validation_data=(test_sequences1, np.array(test_labels)), 
    verbose=2
)
# Out:
# Epoch 1/50
# 85/85 - 6s - 67ms/step - accuracy: 0.6281 - loss: 0.6362 - val_accuracy: 0.6767 - val_loss: 0.5511
# Epoch 2/50
# 85/85 - 1s - 10ms/step - accuracy: 0.6937 - loss: 0.5792 - val_accuracy: 0.6933 - val_loss: 0.5234
# Epoch 3/50
# 85/85 - 1s - 11ms/step - accuracy: 0.7315 - loss: 0.5316 - val_accuracy: 0.7333 - val_loss: 0.5174
# Epoch 4/50
# 85/85 - 1s - 11ms/step - accuracy: 0.7633 - loss: 0.4938 - val_accuracy: 0.7533 - val_loss: 0.5006
# Epoch 5/50
# 85/85 - 1s - 11ms/step - accuracy: 0.7993 - loss: 0.4376 - val_accuracy: 0.7367 - val_loss: 0.4827
# Epoch 6/50
# 85/85 - 1s - 11ms/step - accuracy: 0.8159 - loss: 0.4039 - val_accuracy: 0.7600 - val_loss: 0.4902
# Epoch 7/50
# 85/85 - 1s - 11ms/step - accuracy: 0.8437 - loss: 0.3620 - val_accuracy: 0.7367 - val_loss: 0.5381
# Epoch 8/50
# 85/85 - 1s - 11ms/step - accuracy: 0.8607 - loss: 0.3104 - val_accuracy: 0.7467 - val_loss: 0.5155
# Epoch 9/50
# 85/85 - 1s - 12ms/step - accuracy: 0.8748 - loss: 0.2990 - val_accuracy: 0.7367 - val_loss: 0.5214
# Epoch 10/50
# 85/85 - 1s - 11ms/step - accuracy: 0.8985 - loss: 0.2556 - val_accuracy: 0.7667 - val_loss: 0.5560
# Epoch 11/50
# 85/85 - 1s - 12ms/step - accuracy: 0.8893 - loss: 0.2598 - val_accuracy: 0.7667 - val_loss: 0.5228
# Epoch 12/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9011 - loss: 0.2365 - val_accuracy: 0.7900 - val_loss: 0.5015
# Epoch 13/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9204 - loss: 0.1967 - val_accuracy: 0.7533 - val_loss: 0.5975
# Epoch 14/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9263 - loss: 0.1804 - val_accuracy: 0.7300 - val_loss: 0.6590
# Epoch 15/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9330 - loss: 0.1666 - val_accuracy: 0.7400 - val_loss: 0.7015
# Epoch 16/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9378 - loss: 0.1668 - val_accuracy: 0.7800 - val_loss: 0.6162
# Epoch 17/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9389 - loss: 0.1492 - val_accuracy: 0.7367 - val_loss: 0.7331
# Epoch 18/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9463 - loss: 0.1354 - val_accuracy: 0.7567 - val_loss: 0.6893
# Epoch 19/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9481 - loss: 0.1386 - val_accuracy: 0.7400 - val_loss: 0.7849
# Epoch 20/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9456 - loss: 0.1449 - val_accuracy: 0.7700 - val_loss: 0.6277
# Epoch 21/50
# 85/85 - 1s - 11ms/step - accuracy: 0.9581 - loss: 0.1108 - val_accuracy: 0.7300 - val_loss: 0.9298
# Epoch 22/50
# 85/85 - 1s - 12ms/step - accuracy: 0.9544 - loss: 0.1224 - val_accuracy: 0.7633 - val_loss: 0.7018
# Epoch 23/50
# 85/85 - 1s - 14ms/step - accuracy: 0.9644 - loss: 0.1035 - val_accuracy: 0.7300 - val_loss: 0.8067
# Epoch 24/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9511 - loss: 0.1200 - val_accuracy: 0.7667 - val_loss: 0.6841
# Epoch 25/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9656 - loss: 0.1015 - val_accuracy: 0.7500 - val_loss: 0.7584
# Epoch 26/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9626 - loss: 0.0952 - val_accuracy: 0.7733 - val_loss: 0.6661
# Epoch 27/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9685 - loss: 0.0903 - val_accuracy: 0.7500 - val_loss: 0.8396
# Epoch 28/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9711 - loss: 0.0779 - val_accuracy: 0.7600 - val_loss: 0.8061
# Epoch 29/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9633 - loss: 0.0952 - val_accuracy: 0.7567 - val_loss: 0.7869
# Epoch 30/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9659 - loss: 0.0904 - val_accuracy: 0.7567 - val_loss: 0.8331
# Epoch 31/50
# 85/85 - 1s - 15ms/step - accuracy: 0.9659 - loss: 0.0831 - val_accuracy: 0.7433 - val_loss: 0.8757
# Epoch 32/50
# 85/85 - 1s - 16ms/step - accuracy: 0.9722 - loss: 0.0778 - val_accuracy: 0.7500 - val_loss: 0.8304
# Epoch 33/50
# 85/85 - 1s - 14ms/step - accuracy: 0.9733 - loss: 0.0730 - val_accuracy: 0.7467 - val_loss: 0.8115
# Epoch 34/50
# 85/85 - 1s - 14ms/step - accuracy: 0.9733 - loss: 0.0765 - val_accuracy: 0.7633 - val_loss: 0.7223
# Epoch 35/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9774 - loss: 0.0613 - val_accuracy: 0.7633 - val_loss: 0.8480
# Epoch 36/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9730 - loss: 0.0695 - val_accuracy: 0.7267 - val_loss: 1.0374
# Epoch 37/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9726 - loss: 0.0724 - val_accuracy: 0.7433 - val_loss: 0.8716
# Epoch 38/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9733 - loss: 0.0698 - val_accuracy: 0.7467 - val_loss: 0.8674
# Epoch 39/50
# 85/85 - 1s - 14ms/step - accuracy: 0.9778 - loss: 0.0604 - val_accuracy: 0.7400 - val_loss: 0.8621
# Epoch 40/50
# 85/85 - 1s - 13ms/step - accuracy: 0.9674 - loss: 0.0838 - val_accuracy: 0.7267 - val_loss: 0.8878
# Epoch 41/50
# 85/85 - 1s - 14ms/step - accuracy: 0.9774 - loss: 0.0620 - val_accuracy: 0.7467 - val_loss: 0.9290
# Epoch 42/50
# 85/85 - 1s - 15ms/step - accuracy: 0.9804 - loss: 0.0588 - val_accuracy: 0.7367 - val_loss: 0.9325
# Epoch 43/50
# 85/85 - 1s - 17ms/step - accuracy: 0.9793 - loss: 0.0591 - val_accuracy: 0.7600 - val_loss: 0.9401
# Epoch 44/50
# 85/85 - 1s - 17ms/step - accuracy: 0.9741 - loss: 0.0712 - val_accuracy: 0.7333 - val_loss: 1.0090
# Epoch 45/50
# 85/85 - 1s - 18ms/step - accuracy: 0.9778 - loss: 0.0691 - val_accuracy: 0.7567 - val_loss: 0.8856
# Epoch 46/50
# 85/85 - 1s - 16ms/step - accuracy: 0.9774 - loss: 0.0573 - val_accuracy: 0.7400 - val_loss: 0.9829
# Epoch 47/50
# 85/85 - 1s - 14ms/step - accuracy: 0.9767 - loss: 0.0758 - val_accuracy: 0.7567 - val_loss: 0.9283
# Epoch 48/50
# 85/85 - 1s - 14ms/step - accuracy: 0.9800 - loss: 0.0559 - val_accuracy: 0.7800 - val_loss: 0.8793
# Epoch 49/50
# 85/85 - 1s - 15ms/step - accuracy: 0.9759 - loss: 0.0571 - val_accuracy: 0.7633 - val_loss: 0.8667
# Epoch 50/50
# 85/85 - 1s - 16ms/step - accuracy: 0.9826 - loss: 0.0467 - val_accuracy: 0.7733 - val_loss: 0.9286

# %%
X = "Karry to go to France in gesture of sympathy"

sequences = tokenizer1.texts_to_sequences([X])
sequences = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
if model.predict(sequences, verbose=0)[0][0] >= 0.5:
    print("This news is True")
else:
    print("This news is False")
# Out:
# This news is False
